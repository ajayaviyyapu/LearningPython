# %%
import webbrowser
import requests
from collections import defaultdict
from AjayPackage import string as sym

url_lists = [
    'http://www.python.org',
    'https://chat.deepseek.com/',
    'https://github.com/ajayaviyyapu'
]


#https://chat.deepseek.com/a/chat/s/12d2cb96-e12d-40e3-bd31-eb8c71a12b45  - Silly mistake of DeepSeek

# for url in url_lists :
#    webbrowser.open_new_tab(url)

url_test = 'https://github.com/ajayaviyyapu/LearningPython/blob/main/PythonAssignments/Assignments_File_Handling.ipynb'

response = requests.get(url_test)

print(response)
print(response.status_code)
#print(response.text)
print(response.headers)


url_api = 'https://api.restful-api.dev/objects'
response = requests.get(url_api)
print(response)
print(response.status_code)
resp_list = response.json()
print(resp_list[1])


# Read this url and find the 10 most frequent words. romeo_and_juliet = 'http://www.gutenberg.org/files/1112/1112.txt'
url = 'http://127.0.0.1:5500/PythonAssignments/Data/donald_speech.txt'
response = requests.get(url)
clean_resp = sym.delete_special_characters(response.text)

word_count = defaultdict(int)

for word in clean_resp.split(' ') :
    if word and word is not None :
        word_count[word] += 1

ten_most_freq_words = sorted(word_count.items(),key= lambda item:item[1], reverse=True)[0:10]

print(ten_most_freq_words)

# Read the cats API and cats_api = 'https://api.thecatapi.com/v1/breeds' and find :
# the min, max, mean, median, standard deviation of cats' weight in metric units.
# the min, max, mean, median, standard deviation of cats' lifespan in years.
# Create a frequency table of country and breed of cats
# Read the countries API and find
# the 10 largest countries
# the 10 most spoken languages
# the total number of languages in the countries API
# UCI is one of the most common places to get data sets for data science and machine learning. Read the content of UCL (https://archive.ics.uci.edu/ml/datasets.php). Without additional libraries it will be difficult, so you may try it with BeautifulSoup4
# Out:
# <Response [200]>
# 200
# ...
