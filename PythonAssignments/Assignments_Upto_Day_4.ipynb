# %%
import math
import numpy as np
from numpy.polynomial import Polynomial as P


"""person_info = {'firstname' : 'Ajaya' , 'lastname' : 'Viyyapu'}
print(person_info)
skills = ['HTML', 'CSS', 'JS']
person_info['skills'] = skills
print(person_info)
person_info['skills'].append('Python')
print(person_info)

name,age,isMarried,salary,skillset = 'Aarna',30,False,300000,['HTML','CSS','JS']
print(name,age,isMarried,salary,skillset)

num_1 = 5 #int(input('Enter Number'))
num_2 = 3
powres = pow(num_1, num_2)
print(powres)
floorres = num_1 // num_2
print(floorres)

areares = math.pi * pow(num_1, 2)
print(areares)

circumres = math.pi * 2 * num_1
print(circumres)

x = 3
y = x**2 + 6*x + 9
print(y)

coy = [1,6,9]

xvalue = P(coy)

xval = xvalue.roots()

print(xval)

print(int('9.8') == 10) """

height = 10
breadth = 20
area = height * breadth
print(area)

print(not ('on' in 'Python' and 'on' in 'tempor'))

type({'fn': 'aj', 'ln': 'vi'})

#String Day

str_1 = 'Krishna is god god god always'
print(str_1.lower());

print(str_1[0:7])

print(str_1[::-1]) #Reverse

print(str_1.index('Krishna') == 0)

print(str_1.find('Krishnaa') == 0)

print(str_1.replace('Krishna','Rama'))

print(str_1.split(' '))

str_2 = '{} + {} = {}'.format(str(8),str(6),str(8+6)) + '\n{} - {} = {}'.format(str(8),str(6),str(8-6)) + '\n{} * {} = {}'.format(str(8),str(6),str(8*6))
print(str_2)

str_3 = 'Area of circle with radius {} is {}'.format(str(8),str(math.pi * pow(8,2)))
print(str_3)

str_4 = ['Django', 'Flask', 'Bottle', 'Pyramid', 'Falcon']
print(' # '.join(str_4))

print(str_1.endswith('god'))

print(str_1.startswith('Krishna'))

print(str_1[str_1.find('god'):str_1.rfind('god') + len('god')])

print(str_1[10])

countries = ['Germany', 'France','Belgium','Sweden','Denmark','Finland','Norway','Iceland','Estonia']
gr, fr, bg, sw, *scandic, es = countries
print(gr)
print(fr)
print(bg)
print(sw)
print(scandic)
print(es)
# Out:
# 200
# True
# krishna is god god god always
# Krishna
# syawla dog dog dog si anhsirK
# True
# False
# Rama is god god god always
# ['Krishna', 'is', 'god', 'god', 'god', 'always']
# 8 + 6 = 14
# 8 - 6 = 2
# 8 * 6 = 48
# Area of circle with radius 8 is 201.06192982974676
# Django # Flask # Bottle # Pyramid # Falcon
# False
# True
# god god god
#
# Germany
# France
# Belgium
# Sweden
# ['Denmark', 'Finland', 'Norway', 'Iceland']
# Estonia
