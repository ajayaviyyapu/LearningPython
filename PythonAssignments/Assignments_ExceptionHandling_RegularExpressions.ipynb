# %% [markdown]
# <a href="https://colab.research.google.com/github/ajayaviyyapu/LearningPython/blob/main/PythonAssignments/Assignments_ExceptionHandling_RegularExpressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Packing Lists *
# Unpacking List
#
# Packing Dicts **
# Unpacking Dicts
#
# enumerate
#
# zip
#
# try
# except
# else
# finally

# %%
#Unpack the first five countries and store them in a variable nordic_countries, store Estonia and Russia in es, and ru respectively.
import re
from collections import defaultdict

names = ['Finland', 'Sweden', 'Norway','Denmark','Iceland', 'Estonia','Russia']

*nordic_countries, es ,ru = names

print(nordic_countries)
print(es)
print(ru)

for index, i in enumerate(names) :
 print(index)

#Packing keys so that it can support variable number of arguments
def print_keys(**kwargs) :
  for arg in kwargs :
    print(arg)
  return(kwargs)

#Packing keys so that it can support variable number of arguments
def print_list(*listargs) :
  for arg in listargs :
    print(arg)
  return(listargs)


print(print_keys(name='Ajay',age=38))
print(print_keys(name='Ajay',age=38,city='Frankfurt'))

print(print_list([1,2,4,5,6]))
print(print_list([1,2,4,5,6,7,8,9]))

nested_list = [[1, 2], [3, 4], [5]]
double_the_list = map(lambda sublist : list(map(lambda x:x*2,sublist)), nested_list) #Nested Map Example
print(list(double_the_list))
print(list(double_the_list))

#Using ^

reg_exp = r'^This'  #Statring with This
reg_text = 'is India. This is Germany'
reg_match = re.findall(reg_exp,reg_text)

reg_exp = r'[^A-Za-z ]+'  #Fr Negation
reg_text = 'is India. And in 1980, We are 1 billion in 1990'
reg_match = re.findall(reg_exp,reg_text)
print(reg_match)

#Using Quantifier

reg_exp = r'\d{4}'  #FOr number of matching characters
reg_text = 'is India. And in 1980, We are 1 billion in 1990'
reg_match = re.findall(reg_exp,reg_text)
print(reg_match)

reg_exp = r'\w{5}'  #FOr number of matching characters
reg_text = 'is India. And in 1980, We are 1 billion in 1990'
reg_match = re.findall(reg_exp,reg_text)
print(reg_match)

regex_pattern = r'[a].*'  # . any character, * any character zero or more times
txt = '''Apple and banana are fruits'''
matches = re.findall(regex_pattern, txt)
print(matches)  # ['and banana are fruits']


#What is the most frequent word in the following paragraph?

paragraph = 'I love teaching. If you do not love teaching what else can you love. I love Python if you do not love something which can give you all the capabilities to develop an application what else can you love.'
paragraph = paragraph.replace('.','')
print(paragraph)
paragraph_list = paragraph.split(' ')
print(paragraph_list)

word_count = defaultdict(int)
for word in paragraph_list:
  word_count[word] += 1
print(sorted(word_count.items(), key=lambda item: item[1], reverse=True)[0])

#The position of some particles on the horizontal x-axis are -12, -4, -3 and -1 in the negative direction, 0 at origin, 4 and 8 in the positive direction. Extract these numbers from this whole text and find the distance between the two furthest particles.

sentence = 'The position of some particles on the horizontal x-axis are -12, -4, -3 and -1 in the negative direction, 0 at origin, 4 and 8 in the positive direction. Extract these numbers from this whole text and find the distance between the two furthest particles.'
match_numbers = r'-?\d+'
get_numbers = re.findall(match_numbers,sentence)
get_numbers_sorted = sorted(get_numbers,key= lambda x:int(x))
print(get_numbers_sorted)
print(int(get_numbers_sorted[-1]) - int(get_numbers_sorted[0]))

#Write a pattern which identifies if a string is a valid python variable
#is_valid_variable('first_name') # True
#is_valid_variable('first-name') # False
#is_valid_variable('1first_name') # False
#is_valid_variable('firstname') # True

def is_valid_variable(word) :
  matchexp = r'^[a-zA-Z_][a-zA-Z0-9_]*$'
  print(re.match(matchexp,word))
  return re.match(matchexp,word) is not None

print(is_valid_variable('first_name'))
print(is_valid_variable('fir1st-name'))
print(is_valid_variable('1first_name'))
print(is_valid_variable('firstname'))
print(is_valid_variable('firstname_1name'))


sentence = '''%I $am@% a %tea@cher%, &and& I lo%#ve %tea@ching%;. There $is nothing; &as& mo@re rewarding as educa@ting &and& @emp%o@wering peo@ple. ;I found tea@ching m%o@re interesting tha@n any other %jo@bs. %Do@es thi%s mo@tivate yo@u to be a tea@cher!?'''

#print(clean_text(sentence));
#I am a teacher and I love teaching There is nothing as more rewarding as educating and empowering people I found teaching more interesting than any other jobs Does this motivate you to be a teacher
#print(most_frequent_words(cleaned_text)) # [(3, 'I'), (2, 'teaching'), (2, 'teacher')]

#def clean_text(sentence) :
matchexp = r'[^a-zA-Z0-9 ]'
reg_match = re.findall(matchexp,sentence)
print(reg_match)
for mat in reg_match :
  sentence = sentence.replace(mat,'')
print(sentence)

word_count = defaultdict(int)

for word in sentence.split(' '):
  word_count[word] += 1

print(word_count)
print(sorted(word_count.items(), key= lambda item : item[1],reverse=True)[0])
# Out:
# ['Finland', 'Sweden', 'Norway', 'Denmark', 'Iceland']
# Estonia
# Russia
# 0
# 1
# 2
# 3
# 4
# 5
# 6
# name
# age
# {'name': 'Ajay', 'age': 38}
# name
# age
# city
# {'name': 'Ajay', 'age': 38, 'city': 'Frankfurt'}
# [1, 2, 4, 5, 6]
# ([1, 2, 4, 5, 6],)
# [1, 2, 4, 5, 6, 7, 8, 9]
# ([1, 2, 4, 5, 6, 7, 8, 9],)
# [[2, 4], [6, 8], [10]]
# []
# ['.', '1980,', '1', '1990']
# ['1980', '1990']
# ['India', 'billi']
# ['and banana are fruits']
# I love teaching If you do not love teaching what else can you love I love Python if you do not love something which can give you all the capabilities to develop an application what else can you love
# ['I', 'love', 'teaching', 'If', 'you', 'do', 'not', 'love', 'teaching', 'what', 'else', 'can', 'you', 'love', 'I', 'love', 'Python', 'if', 'you', 'do', 'not', 'love', 'something', 'which', 'can', 'give', 'you', 'all', 'the', 'capabilities', 'to', 'develop', 'an', 'application', 'what', 'else', 'can', 'you', 'love']
# ('love', 6)
# ...

# %%
import json
list_str = 'michael.langhans,patrick.besand,raphael.frey,sven.buelow,sven.kuehn,sylwia.trzcielinska,tanja.leithold,wolfgang.stroeher,yuecel.oeztuerk'

list_new = list_str.split(',')
print(list_new)
dict_new = dict()

list_dict = list(map(lambda x: {'username' :x}, list_new))
print(list_dict)

json_string = json.dumps(list_dict , indent=2)
print(json_string)
# Out:
# ['michael.langhans', 'patrick.besand', 'raphael.frey', 'sven.buelow', 'sven.kuehn', 'sylwia.trzcielinska', 'tanja.leithold', 'wolfgang.stroeher', 'yuecel.oeztuerk']
# [{'username': 'michael.langhans'}, {'username': 'patrick.besand'}, {'username': 'raphael.frey'}, {'username': 'sven.buelow'}, {'username': 'sven.kuehn'}, {'username': 'sylwia.trzcielinska'}, {'username': 'tanja.leithold'}, {'username': 'wolfgang.stroeher'}, {'username': 'yuecel.oeztuerk'}]
# [
#   {
#     "username": "michael.langhans"
#   },
#   {
#     "username": "patrick.besand"
#   },
#   {
#     "username": "raphael.frey"
#   },
#   {
#     "username": "sven.buelow"
#   },
#   {
#     "username": "sven.kuehn"
#   },
#   {
#     "username": "sylwia.trzcielinska"
#   },
#   {
#     "username": "tanja.leithold"
#   },
#   {
#     "username": "wolfgang.stroeher"
#   },
#   {
#     "username": "yuecel.oeztuerk"
#   }
# ]
