# %% [markdown]
# <a href="https://colab.research.google.com/github/ajayaviyyapu/LearningPython/blob/main/PythonAssignments/Assignments_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Write a function called check-season, it takes a month parameter and returns the season: Autumn, Winter, Spring or Summer.

season_dict_list = [ {'name':'Winter', 'months': ['December','January','February']},
                     {'name':'Spring', 'months': ['March','April','May']},
                     {'name':'Summmer','months': ['June','July','August']},
                     {'name':'Autumn' ,'months': ['Septmeber','October','November']} ]

def check_season(month) :
  for season in season_dict_list :
    flag = 0
    if(season.get('months') is not None and season.get('months') and list(season.get('months')).count(month) > 0) :
      flag = 1
      break
  return season.get('name') if flag == 1 else 'not determinable because of Invalid Month'

print('Season is {}'.format(check_season('sadsad')))

#Write a function called calculate_slope which return the slope of a linear equations
# Out:
# Season is not determinable because of Invalid Month
